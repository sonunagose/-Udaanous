# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
data = pd.read_excel('C:/Users/JOHN/Desktop/practice_data.xlsx')

# %%
data
# Out:
#     EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0            1    Male            Sales            20             High
# 1            2  Female        Marketing            22           Medium
# 2            3    Male  Human Resources            25             High
# 3            4    Male      Engineering            19              Low
# 4            5  Female          Finance            23           Medium
# 5            6    Male            Sales            21             High
# 6            7  Female        Marketing            24              Low
# 7            8    Male  Human Resources            18           Medium
# 8            9    Male      Engineering            20             High
# 9           10  Female          Finance            22           Medium
# 10          11    Male            Sales            25             High
# 11          12  Female        Marketing            19              Low
# ...

# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

data = pd.read_excel('C:/Users/JOHN/Desktop/practice_data.xlsx')

encoder = LabelEncoder()

data['gender'] = encoder.fit_transform(data['gender'])

print(data.head())
# Out:
#    EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0           1       1            Sales            20             High
# 1           2       0        Marketing            22           Medium
# 2           3       1  Human Resources            25             High
# 3           4       1      Engineering            19              Low
# 4           5       0          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
### The LabelEncoder Assign

0 to the first alphabetical value i.e., Female

1 to the second i.e., Male

So the original value at index 0 is "Male", which would be encoded as 1.

# %% [markdown]
# # The first value of the gender column after label encoding is 1

# %% [markdown]
# # 48.Selecting Features

# %%
import pandas as pd

data = pd.read_excel('C:/Users/JOHN/Desktop/practice_data.xlsx')
X = data.drop(['EmployeeID', 'churned'], axis=1)
y = data['churned']

X_encoded = pd.get_dummies(X, drop_first=True)

print(X_encoded.head())
print(y.head())
# Out:
#    Days Present  Task Completion Rates  Interpersonal Skills Rating  \
# 0            20                     85                            8
# 1            22                     90                            7
# 2            25                     80                            9
# 3            19                     75                            6
# 4            23                     85                            7
#
#    Decision-Making Skills Rating  Sales Revenue Generated  gender_Male  \
# 0                              7                    51638         True
# 1                              6                    97797        False
# 2                              8                    95341         True
# 3                              5                    91806         True
# 4                              7                    64247        False
#
#    department_Finance  department_Human Resources  department_Marketing  \
# ...

# %%
X
# Out:
#     gender       department  Days Present Accuracy of Work  \
# 0     Male            Sales            20             High
# 1   Female        Marketing            22           Medium
# 2     Male  Human Resources            25             High
# 3     Male      Engineering            19              Low
# 4   Female          Finance            23           Medium
# 5     Male            Sales            21             High
# 6   Female        Marketing            24              Low
# 7     Male  Human Resources            18           Medium
# 8     Male      Engineering            20             High
# 9   Female          Finance            22           Medium
# 10    Male            Sales            25             High
# 11  Female        Marketing            19              Low
# 12    Male  Human Resources            23           Medium
# 13    Male      Engineering            21             High
# 14  Female          Finance            24              Low
# ...

# %%
x = data.drop(['Task Completion Rates','Meeting Project Deadlines'], axis=1)
y
# Out:
# 0      No
# 1     Yes
# 2      No
# 3      No
# 4     Yes
# 5      No
# 6     Yes
# 7      No
# 8      No
# 9     Yes
# 10     No
# 11    Yes
# 12     No
# 13     No
# 14    Yes
# 15     No
# 16    Yes
# 17     No
# 18     No
# 19    Yes
# 20     No
# 21    Yes
# 22     No
# 23     No
# 24    Yes
# 25    Yes
# 26     No
# 27    Yes
# 28     No
# 29     No
# 30    Yes
# Name: churned, dtype: object

# %%
x
# Out:
#     EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0            1    Male            Sales            20             High
# 1            2  Female        Marketing            22           Medium
# 2            3    Male  Human Resources            25             High
# 3            4    Male      Engineering            19              Low
# 4            5  Female          Finance            23           Medium
# 5            6    Male            Sales            21             High
# 6            7  Female        Marketing            24              Low
# 7            8    Male  Human Resources            18           Medium
# 8            9    Male      Engineering            20             High
# 9           10  Female          Finance            22           Medium
# 10          11    Male            Sales            25             High
# 11          12  Female        Marketing            19              Low
# ...

# %% [markdown]
# # 49.Standard Scalling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features = pd.DataFrame(scaled, columns=X_encoded.columns)

print("Original Features:\n", X_encoded)
print("\nScaled Features:\n", scaled_features)
# Out:
# Original Features:
#      Days Present  Task Completion Rates  Interpersonal Skills Rating  \
# 0             20                     85                            8
# 1             22                     90                            7
# 2             25                     80                            9
# 3             19                     75                            6
# 4             23                     85                            7
# 5             21                     95                            8
# 6             24                     70                            5
# 7             18                     80                            6
# 8             20                     90                            8
# 9             22                     85                            7
# 10            25                     75                            9
# 11            19                     70                            6
# ...

# %% [markdown]
# # 50.Minimum & Maximum Scalling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled = scaler.fit_transform(X_encoded)
scaled_features = pd.DataFrame(scaled, columns=X_encoded.columns)

print("Original Encoded Features:\n", X_encoded.head())
print("\nMin-Max Scaled Features (0 to 1):\n", scaled_features.head())
# Out:
# Original Encoded Features:
#     Days Present  Task Completion Rates  Interpersonal Skills Rating  \
# 0            20                     85                            8
# 1            22                     90                            7
# 2            25                     80                            9
#
#    Decision-Making Skills Rating  Sales Revenue Generated  gender_Male  \
# 0                              7                    51638         True
# 1                              6                    97797        False
# 2                              8                    95341         True
#
#    department_Marketing  department_Sales  Accuracy of Work_Medium  \
# 0                 False              True                    False
# 1                  True             False                     True
# 2                 False             False                    False
#
#    Meeting Project Deadlines_Yes
# 0                           True
# 1                           True
# ...

# %% [markdown]
# # 51 PCA

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt


# Drop ID and target columns
X = data.drop(['EmployeeID', 'churned'], axis=1)
y = data['churned']

# encode categorical features
X_encoded = pd.get_dummies(X, drop_first=True)

# Scale features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_encoded)

# PCA
pca = PCA()
temp_pca = pca.fit_transform(X_scaled)

evr = pca.explained_variance_ratio_

# Plot explained variance
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(evr) + 1), evr, marker='o')
plt.title('Explained Variance Ratio by PCA Components')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()

# %% [markdown]
# # 52 Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(scaled, y, test_size=0.2, random_state=42)

print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (2, 10)
# x_test shape: (1, 10)
# y_train shape: (2,)
# y_test shape: (1,)
