# %% [markdown]
# ## Problem 1:

# %%
P = 5000  # Principal amount in dollars
r = 0.05  # Annual interest rate (5%)
t = 10     # Time in years
n = 12    # Compounded monthly

def calculate_compound_interest(P, r, t, n):
    final_amount = P * (1 + r/n) ** (n*t)
    return final_amount

round(calculate_compound_interest(5000, 0.05, 10, 12),2)
# Out:
# 8235.05

# %% [markdown]
# ## Problem 2:

# %%
principal = 700000  # Loan amount in dollars
annual_rate = 6.5   # Annual interest rate (7.5%)
tenure = 30         # Loan tenure in years

def calculate_emi(P, r, n):
    monthly_rate = (annual_rate/100)/12
    total_months = tenure * 12
    emi_amount = (P * monthly_rate * ((1 + monthly_rate) ** total_months)) / (((1 + monthly_rate) ** total_months) - 1)
    return emi_amount

round(calculate_emi(700000, 6.5, 30),)
# Out:
# 4424

# %% [markdown]
# ## Problem 3:

# %%
weight = 90  # Weight in kilograms
height = 1.85  # Height in meters

def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    if bmi < 18.5:
        assessment = "Underweight"
    elif 18.5 <= bmi < 25:
        assessment = "Normal weight"
    elif 25 <= bmi < 30:
        assessment = "Overweight"
    else:
        assessment = "Obesity"
    return bmi, assessment

calculate_bmi(90, 1.85)
# Out:
# (26.296566837107374, 'Overweight')

# %% [markdown]
# ## Problem:
#
# Imagine you are managing a small library and need a system to track books and their availability. Each book has details like the title, author, and availability status (whether it’s borrowed or not). You want to build a system that allows:
#
# 1. Adding books to the library.
# 2. Checking if a book is available.
# 3. Borrowing a book (marking it as borrowed).
# 4. Returning a book (marking it as available).
#
# You will solve this using classes and objects.

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self. author = author
        self.is_available = True
    def borrow(self):
        if self.is_available:
            self.is_available = False
            return f"You have borrowed '{self.title}'."
        else:
            return f"Sorry, '{self.title}' is already borrowed."
    def return_book(self):
        if not self.is_available:
            self.is_available = True 
            return f"'{self.title}' has been returned. Thank you!"
        else:
            return f"{self.title}' is already in the library."
    def check_availability(self):
        return f"'{self.title}' is {'available' if self.is_available else 'not available'}"

# %%
library = Book("To Kill a Mockingbird", "Harper Lee")
print(library.check_availability())
# Out:
# 'To Kill a Mockingbird' is available

# %%
print(library.borrow())
# Out:
# You have borrowed 'To Kill a Mockingbird'.

# %%
print(library.check_availability())
# Out:
# 'To Kill a Mockingbird' is not available

# %%
print(library.return_book())
# Out:
# 'To Kill a Mockingbird' has been returned. Thank you!

# %%
print(library.check_availability())
# Out:
# 'To Kill a Mockingbird' is available

# %%
print(library.return_book())
# Out:
# To Kill a Mockingbird' is already in the library.

# %%
try:
    num1 = float(input("Enter the numerator: "))
    num2 = float(input("Enter the denominator: "))
    result = num1 / num2
except ZeroDivisionError:
    print("Division by zero is not allowed.")
except ValueError:
    print("Invalid input. Please enter numeric values.")
else:
    print("Success!", result)
# Out:
# Enter the numerator:  100
# Enter the denominator:  50
# Success! 2.0

# %%
try:
    num1 = float(input("Enter the numerator: "))
    num2 = float(input("Enter the denominator: "))
    result = num1 / num2
except ZeroDivisionError:
    print("Division by zero is not allowed.")
except ValueError:
    print("Invalid input. Please enter numeric values.")
else:
    print("Success!", result)
# Out:
# Enter the numerator:  500
# Enter the denominator:  3
# Success! 166.66666666666666
